# %% [markdown]
# <h1><u>RNN thesis</u></h1>
# <h4>Omer Nivron</h4>
# 15098443

# %% [markdown]
# <h3>Package loading</h3>

# %%
import numpy as np
import sys as sys
import random as rd
import tensorflow as tf
import gzip
from __future__ import division
from tensorflow.python.ops import array_ops, control_flow_ops
import pandas as pd
import os
import math
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import time
import csv

# %%
import numpy as np
import boto3
import tensorflow as tf
import pandas as pd
import os
import cStringIO
#! sudo /mnt1/anaconda2/bin/pip install s3fs
! sudo pip install s3fs
import s3fs
pd.options.display.max_columns = None
pd.options.display.max_rows = None
# Out:
# Collecting s3fs
#   Downloading s3fs-0.1.2.tar.gz
# Requirement already satisfied: boto3 in /usr/lib/python2.7/dist-packages (from s3fs)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/lib/python2.7/dist-packages (from boto3->s3fs)
# Requirement already satisfied: s3transfer<0.2.0,>=0.1.10 in /usr/lib/python2.7/dist-packages (from boto3->s3fs)
# Requirement already satisfied: botocore<1.6.0,>=1.5.0 in /usr/lib/python2.7/dist-packages (from boto3->s3fs)
# Requirement already satisfied: futures<4.0.0,>=2.2.0; python_version == "2.6" or python_version == "2.7" in /usr/lib/python2.7/dist-packages (from s3transfer<0.2.0,>=0.1.10->boto3->s3fs)
# Requirement already satisfied: docutils>=0.10 in /usr/lib/python2.7/dist-packages (from botocore<1.6.0,>=1.5.0->boto3->s3fs)
# Collecting python-dateutil<3.0.0,>=2.1 (from botocore<1.6.0,>=1.5.0->boto3->s3fs)
#   Downloading python_dateutil-2.6.1-py2.py3-none-any.whl (194kB)
#     100% |████████████████████████████████| 194kB 4.1MB/s ta 0:00:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python2.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.6.0,>=1.5.0->boto3->s3fs)
# Building wheels for collected packages: s3fs
#   Running setup.py bdist_wheel for s3fs ... done
#   Stored in directory: /root/.cache/pip/wheels/ad/85/31/07e4a6c225e249b5e55116d9dcf94282c14e7f8fcc65969d22
# Successfully built s3fs
# Installing collected packages: s3fs, python-dateutil
#   Found existing installation: python-dateutil 1.5
#     Uninstalling python-dateutil-1.5:
#       Successfully uninstalled python-dateutil-1.5
# Successfully installed python-dateutil-2.6.1 s3fs-0.1.2

# %% [markdown]
# ### Data creation

# %%
def np_pad_tr_x(x_tr, batch_size, str_idx, zero_array_x, length_vec):
    start = 0
    for i in range(batch_size):
        if i > 0:
            end = end + length_vec[i] 
        else:
            end = length_vec[0]
        zero_array_x[ str_idx[i] : (str_idx[i] + length_vec[i]) ] = x_tr[ start : end ] 
        start = end

    return(zero_array_x)

# %%
def range_bet_col_t_col_n_append(col_1 ,col_2):
    app_ranges=[]
    for i in range(col_1.shape[0]):
        single_range = range((col_1[i]).astype(int), (col_2[i]).astype(int))
        app_ranges = np.append(app_ranges, single_range)
    return(app_ranges)

# %%
def algeb_geom_series(mode ,start ,jump ,length):
    u = np.empty((length,))
    u[0] = start
    u[1:] = jump
    if (mode == 0):
        series=np.cumsum(u)
    if (mode == 1):
        series=np.cumprod(u)
    return(series)

# %%
def sort_pd_df_by_ext_vec(df,ext_sor_vec, cols):
    df_s = df[((df[cols[0]]).astype(int)).isin(ext_sor_vec)] #
    df_s['sort_cat'] = pd.Categorical(df_s[cols[0]],categories = ext_sor_vec,ordered = True)
    if len(cols) > 1:
        df_s.sort_values(['sort_cat',cols[1]] ,inplace = True)
    
    else:
        df_s.sort_values(['sort_cat'],inplace = True) 
    
    df_s.reset_index(inplace = True)
    df_ = df_s.drop(['sort_cat','index'] ,axis = 1)
    
    return(df_)

# %%
def rnn_model(model ,n_hidden ,layers):
    if (layers == 1):
        if(model == 'lstm'):
            cell = tf.nn.rnn_cell.LSTMCell(n_hidden ,state_is_tuple=True)
        else:
            cell = tf.nn.rnn_cell.GRUCell(n_hidden)   
    else:
        if(model == 'lstm'):
            lstm = tf.nn.rnn_cell.LSTMCell(n_hidden ,state_is_tuple=True)
            cell = tf.nn.rnn_cell.MultiRNNCell([lstm]*layers)

        else:
            gru = tf.nn.rnn_cell.GRUCell(n_hidden)
            cell = tf.nn.rnn_cell.MultiRNNCell([gru] * layers)
    return(cell)

# %% [markdown]
# ############################################

# %% [markdown]
# Loading Fake Data

# %%
def trainSamples(viewers,videos,probab,viewerFeat,videoFeat,contxFeat):
    trData = {} # trData = Dictionary with training data. This is histrory of viewer and video iteraction
    X = {} # X  = Dictionary with viewer features as arrays
    Y ={} # Y  = Dictionary with video features as arrays
    for i in range(viewers):
        X[i] = np.random.rand(viewerFeat)
        a = 0 # timing of the video for a particular user,... 
                #to give the order in which the videos have been watched
        for j in range(videos):
            if int(np.random.binomial(1,probab ,1)[0]):
                trData[(i,j,a)] = np.random.rand(contxFeat)
                a+=1 # when a video is watched, we increase the value of a by 1 
            if i==0:
                Y[j] = np.random.rand(videoFeat)
    return X,Y,trData

# %%
viewers = 1000  #number of viewers
videos =1000  #number of videos
probab = 0.05  #probability of a viewer watching any one video
viewerFeat = 310  #number of features describing a veiwer
videoFeat = 300   #number of features describing a video
contxFeat = 15 # number of contextual features
# X  = Dictionary with viewer features as arrays
# Y  = Dictionary with video features as arrays
# trData = Dictionary with training data. This is histrory of viewer and video iteraction
X ,Y ,trData = trainSamples(viewers ,videos ,probab ,viewerFeat ,videoFeat ,contxFeat)

# %% [markdown]
# ### transform a dict to numpy array

# %%
user_feat_inp = np.array([X[key] for key in sorted(X.keys())]) 
vid_feat_inp = np.array([Y[key] for key in sorted(Y.keys())])

# %% [markdown]
# ### Add a column key specifying user

# %%
key_user = np.asarray(range(user_feat_inp.shape[0])).reshape(user_feat_inp.shape[0] ,1)
key_vid = np.asarray(range(vid_feat_inp.shape[0])).reshape(vid_feat_inp.shape[0] ,1)
user_feat_inp_w_key = np.concatenate((user_feat_inp ,key_user),axis = 1)
vid_feat_inp_w_key = np.concatenate((vid_feat_inp ,key_vid),axis = 1)
user_vid_time = trData.keys()

# %% [markdown]
# ### transform numpy to pandas df in order to use easy merging

# %%
user_feat_inp_w_key_df = pd.DataFrame(user_feat_inp_w_key) 
vid_feat_inp_w_key_df = pd.DataFrame(vid_feat_inp_w_key)
user_vid_time_df = pd.DataFrame(user_vid_time)

# %% [markdown]
# ## Construct true_y

# %% [markdown]
# ### sort values by user and time watched

# %%
rr = user_vid_time_df.sort_values([0 ,2]).reset_index()

# %% [markdown]
# ### get categorical column for each video with 1 where watched and 0 otherwise

# %%
h = pd.get_dummies(rr[1],prefix = 'vid_')
y_tr_p_w = pd.concat([rr.reset_index(drop = True), h], axis = 1)
y_tr_p_w.rename(columns = {0: 'user'}, inplace = True)
y_tr_p_w.rename(columns = {1: 'mov'}, inplace = True)
y_tr_p_w.rename(columns = {2: 'rank'}, inplace = True)
y_tr_p_w['desired'] = np.argmax(np.array(y_tr_p_w.iloc[:,4:]) ,1)

# %% [markdown]
# ### We get for each user one row with 1's in the positions watched incl. user column(0)

# %%
max_watch = (y_tr_p_w.groupby('user',axis = 0).sum().iloc[:
                                ,int(np.array(np.where(y_tr_p_w.columns=='rank'))):-1].sum(axis=1)).reset_index()

# %% [markdown]
# ### Merge two pandas df

# %%
vid_feat_inp_w_key_df.rename(columns = {300: 'mov_id'}, inplace = True)
user_feat_inp_w_key_df.rename(columns = {310: 'user_id'}, inplace = True)
user_vid_time_df.rename(columns = {0: 'user_id'}, inplace = True)
user_vid_time_df.rename(columns = {1: 'mov_id'}, inplace = True)
user_w_vid_tim_and_feat = user_vid_time_df.merge(user_feat_inp_w_key_df 
                                                 ,how = 'inner',on = 'user_id', sort = False)
user_vid_time_vidfeat_usefit = user_w_vid_tim_and_feat.merge(vid_feat_inp_w_key_df 
                                                             ,how = 'inner' ,on='mov_id' ,sort = False)
user_vid_time_vidfeat_usefit.rename(columns={'2_x': 'time_watch'} ,inplace=True)
user_vid_time_vidfeat_usefit_sorted = user_vid_time_vidfeat_usefit.sort_values(['user_id', 'time_watch']) 
cols_to_del = [user_vid_time_vidfeat_usefit_sorted.columns.get_loc("user_id")
             ,user_vid_time_vidfeat_usefit_sorted.columns.get_loc("mov_id")
             ,user_vid_time_vidfeat_usefit_sorted.columns.get_loc("time_watch")]

# %% [markdown]
# ### Split training and testing data

# %%
tr_users = viewers * 0.8
tr_y = y_tr_p_w[y_tr_p_w['user'] < tr_users]
te_y = y_tr_p_w[~y_tr_p_w['user'].isin(tr_y['user'])]

# %% [markdown]
# ################################################

# %% [markdown]
# # S3 loading

# %%
bucket = 'c4-ati'
dataLoc = 'ampapalika/rnn/dataHashed/'

def dataLoad(bucket, dataLoc,valLoc):
    '''
    Function which returns list of all objects in s3 bucket path
    '''
    s3_client = boto3.client('s3')
    path  = dataLoc+valLoc
    response = s3_client.list_objects(Bucket = bucket,Prefix = path)
    file_list = list()
    for file in response['Contents']:
        name = file['Key'].rsplit('/', 1)
        file_list.append(name[1])
        
    fileKey= dataLoc+valLoc+'/'+file_list[1]
    s3_client = boto3.client('s3')
    obj = s3_client.get_object(Bucket='c4-ati', Key=fileKey)   
    full_data = pd.DataFrame({0: []})#, 1: []
    f = cStringIO.StringIO(obj['Body'].read())
    
    for df in pd.read_csv(f,header=None, chunksize=10000,dtype={0: int}):
        full_data = pd.concat([full_data,df], ignore_index=True)
    
    return full_data


def loadTrainDF(bucket, dataLoc,valLoc):
   
    full_data = dataLoad(bucket, dataLoc,valLoc)
    full_data.rename(columns={1: 'movie_id',2: 'time_watch',3: 'rank',0: 'user_id'}, inplace=True)
    del full_data['time_watch']
    return full_data.astype('float32')

def loadUserFeatDF(bucket, dataLoc, valLoc):
    full_data = dataLoad(bucket, dataLoc,valLoc)
    full_data.rename(columns={0: 'user_id'}, inplace=True)
    return full_data.astype('float32')

def loadVideoFeatDF(bucket, dataLoc, valLoc):
    full_data = dataLoad(bucket, dataLoc,valLoc)
    full_data.rename(columns={0: 'movie_id'}, inplace=True)
    return full_data.astype('float32')


user_feat_inp_w_key_df = loadUserFeatDF(bucket, dataLoc,'userFeatIndex2TGenre')
vid_feat_inp_w_key_df = loadVideoFeatDF(bucket, dataLoc,'videoFeatGenre')
user_vid_time_df = loadTrainDF(bucket,dataLoc, 'trainDataIndex2TU2TVGenre')
user_vid_time_df2NS = loadTrainDF(bucket,dataLoc, 'trainDataIndexTU2TVNSGenre')

user_vid_time_df_inp = user_vid_time_df
for user in (np.array(user_vid_time_df_inp["user_id"].unique())):
    a = max(user_vid_time_df_inp.loc[user_vid_time_df_inp["user_id"]== user, "rank"])
    user_vid_time_df_inp = user_vid_time_df_inp[~((user_vid_time_df_inp["rank"] == a) & (user_vid_time_df_inp["user_id"] == user))]

num_user_feat, num_video_feat = user_feat_inp_w_key_df.shape[1] -1 , vid_feat_inp_w_key_df.shape[1] -1
num_users, contex_feat = user_feat_inp_w_key_df.shape[0], len(user_vid_time_df.columns[3:])

user_vid_time_df_sort=user_vid_time_df[["user_id",'movie_id',"rank"]].sort_values(["user_id","rank"])
user_vid_time_df_sort = user_vid_time_df_sort.reset_index(drop=True)

h=pd.get_dummies(user_vid_time_df_sort["movie_id"],sparse=True,prefix='vid_')

y_tr_p_w=pd.concat([user_vid_time_df_sort.reset_index(drop=True), h], axis=1)
y_tr_p_w['desired'] = np.argmax(np.array(y_tr_p_w.iloc[:,3:]) ,1)
y_tr_p_w = y_tr_p_w[y_tr_p_w["rank"] > 3]

max_watch = (y_tr_p_w.groupby('user_id',axis = 0).sum().iloc[:
                                ,((list(np.where(y_tr_p_w.columns=="rank")[0])[0])):-1].sum(axis=1)).reset_index()

user_w_vid_tim_and_feat = user_vid_time_df_inp.merge(user_feat_inp_w_key_df 
                                                 ,how = 'inner',on = 'user_id', sort = False)
user_vid_time_vidfeat_usefit = user_w_vid_tim_and_feat.merge(vid_feat_inp_w_key_df 
                                                             ,how = 'inner' ,on='movie_id' ,sort = False)
user_vid_time_vidfeat_usefit_sorted = user_vid_time_vidfeat_usefit.sort_values(['user_id', 'rank']) 

user_vid_time_df2NS_10 = user_vid_time_df2NS[user_vid_time_df2NS.user_id.isin(user_vid_time_df2NS[user_vid_time_df2NS['rank']==10]['user_id'])]
user_vid_time_df2NS_top10 =user_vid_time_df2NS_10[user_vid_time_df2NS_10['rank']<=10]
user_vid_time_df2NS_top10 = user_vid_time_df2NS_top10[['user_id','movie_id','rank']]

_user_vid_time_df2NS_top10 = user_vid_time_df2NS_top10.merge(vid_feat_inp_w_key_df 
                                                             ,how = 'inner' ,on='movie_id' ,sort = False)

_user_vid_time_df2NS_top10 = _user_vid_time_df2NS_top10.sort_values(["user_id", "rank"])

train_dislike = _user_vid_time_df2NS_top10[:10000]

test_dislike = _user_vid_time_df2NS_top10[10000:]

user_tr_choice = train_dislike["user_id"].unique()
user_te_choice = test_dislike["user_id"].unique()

tr_y = y_tr_p_w[y_tr_p_w['user_id'].isin(user_tr_choice)]
te_y = y_tr_p_w[y_tr_p_w['user_id'].isin(user_te_choice)]

tr_users = len(user_tr_choice)

tr_likes = user_vid_time_vidfeat_usefit_sorted[user_vid_time_vidfeat_usefit_sorted["user_id"]
                                            .isin(user_tr_choice)]

te_likes = user_vid_time_vidfeat_usefit_sorted[user_vid_time_vidfeat_usefit_sorted["user_id"]
                                            .isin(user_te_choice)]

# %%
a = pd.DataFrame(y_tr_p_w.sum())

# %%
b = a[3:-1]

# %%
b = a[3:-1]

# %%
len(b)
# Out:
# 7724

# %%
c = b.sort_values(by=0,ascending=False)

# %%
c
# Out:
#                  0
# vid__3840.0  518.0
# vid__5509.0  508.0
# vid__5185.0  507.0
# vid__5177.0  506.0
# vid__5559.0  505.0
# vid__3979.0  505.0
# vid__4019.0  503.0
# vid__4173.0  501.0
# vid__5564.0  497.0
# vid__3937.0  480.0
# vid__6715.0  473.0
# vid__3905.0  467.0
# vid__4062.0  467.0
# vid__5495.0  464.0
# vid__7292.0  456.0
# vid__5400.0  448.0
# vid__7358.0  417.0
# vid__4266.0  404.0
# vid__7236.0  404.0
# vid__4324.0  401.0
# vid__1855.0  397.0
# vid__6752.0  392.0
# vid__6904.0  390.0
# vid__4345.0  388.0
# vid__7476.0  386.0
# vid__4466.0  385.0
# vid__1975.0  384.0
# vid__5661.0  383.0
# vid__6782.0  382.0
# vid__579.0   380.0
# vid__1890.0  379.0
# vid__1766.0  378.0
# vid__5091.0  378.0
# vid__4658.0  378.0
# vid__5706.0  377.0
# vid__4292.0  376.0
# vid__6656.0  376.0
# vid__6728.0  375.0
# vid__4374.0  375.0
# vid__1731.0  374.0
# vid__6777.0  374.0
# vid__4486.0  373.0
# vid__6802.0  373.0
# vid__7419.0  372.0
# vid__7381.0  372.0
# vid__4238.0  371.0
# vid__76.0    371.0
# vid__435.0   370.0
# vid__4731.0  369.0
# vid__7075.0  369.0
# vid__4581.0  367.0
# vid__4516.0  367.0
# vid__4690.0  367.0
# vid__1722.0  367.0
# vid__413.0   367.0
# vid__1587.0  366.0
# vid__2854.0  366.0
# vid__577.0   365.0
# vid__314.0   364.0
# vid__4624.0  364.0
# vid__364.0   364.0
# vid__6808.0  364.0
# vid__4172.0  363.0
# vid__542.0   363.0
# vid__4202.0  363.0
# vid__3935.0  362.0
# vid__480.0   362.0
# vid__2894.0  362.0
# vid__5364.0  361.0
# vid__5245.0  361.0
# vid__4319.0  360.0
# vid__7399.0  360.0
# vid__6700.0  360.0
# vid__6680.0  359.0
# vid__6875.0  359.0
# vid__4160.0  359.0
# vid__494.0     1.0
# vid__191.0     1.0
# vid__6037.0    1.0
# vid__70.0      1.0
# vid__5968.0    1.0
# vid__5973.0    1.0
# vid__5975.0    1.0
# vid__3882.0    1.0
# vid__1643.0    1.0
# vid__3889.0    1.0
# vid__3296.0    1.0
# vid__6002.0    1.0
# vid__2284.0    1.0
# vid__5233.0    1.0
# vid__6011.0    1.0
# vid__74.0      1.0
# vid__3917.0    1.0
# vid__4015.0    1.0
# vid__5112.0    1.0
# vid__2380.0    1.0
# vid__5016.0    1.0
# vid__664.0     1.0
# vid__7193.0    1.0
# vid__2458.0    1.0
# vid__4088.0    1.0
# vid__6225.0    1.0
# vid__3129.0    1.0
# vid__676.0     1.0
# vid__4992.0    1.0
# vid__3123.0    1.0
# vid__4097.0    1.0
# vid__7172.0    1.0
# vid__6233.0    1.0
# vid__6242.0    1.0
# vid__7156.0    1.0
# vid__698.0     1.0
# vid__4980.0    1.0
# vid__3093.0    1.0
# vid__6261.0    1.0
# vid__4961.0    1.0
# vid__709.0     1.0
# vid__4952.0    1.0
# vid__714.0     1.0
# vid__2498.0    1.0
# vid__4133.0    1.0
# vid__6292.0    1.0
# vid__7120.0    1.0
# vid__725.0     1.0
# vid__2511.0    1.0
# vid__4922.0    1.0
# vid__4023.0    1.0
# vid__7200.0    1.0
# vid__5026.0    1.0
# vid__2408.0    1.0
# vid__5104.0    1.0
# vid__615.0     1.0
# vid__5094.0    1.0
# vid__6141.0    1.0
# vid__7253.0    1.0
# vid__620.0     1.0
# vid__231.0     1.0
# vid__3171.0    1.0
# vid__4039.0    1.0
# vid__3170.0    1.0
# vid__634.0     1.0
# vid__5077.0    1.0
# vid__2870.0    1.0
# vid__6165.0    1.0
# vid__3560.0    1.0
# vid__3153.0    1.0
# vid__3166.0    1.0
# vid__6201.0    1.0
# vid__2413.0    1.0
# vid__2430.0    1.0
# vid__7229.0    1.0
# vid__2433.0    1.0
# vid__5040.0    1.0
# vid__7222.0    1.0
# vid__7220.0    1.0
# vid__4060.0    1.0
# vid__6198.0    1.0
# vid__6950.0    0.0
# vid__1040.0    0.0
# vid__3314.0    0.0
# vid__4430.0    0.0
# vid__790.0     0.0
# vid__5836.0    0.0
# vid__2693.0    0.0
# vid__4072.0    0.0
# vid__3370.0    0.0

# %%
d = [sum(c[:250])/sum(c),sum(c[:500])/sum(c),sum(c[:1000])/sum(c),sum(c[:2000])/sum(c),sum(c[:3000])/sum(c),sum(c[:4000])/sum(c), sum(c[:5000])/sum(c)]

# %%
e = [250/len(b),500/len(b),1000/len(b),2000/len(b),3000/len(b),4000/len(b),5000/len(b)]

# %%
d
# Out:
# [0.18475623114646353,
#  0.32046798901228535,
#  0.50211917962891184,
#  0.72049579534538832,
#  0.84572540824752696,
#  0.92180943393046733,
#  0.9644479178954819]

# %%
e
# Out:
# [0.03236664940445365,
#  0.0647332988089073,
#  0.1294665976178146,
#  0.2589331952356292,
#  0.38839979285344384,
#  0.5178663904712584,
#  0.647332988089073]

# %%
>>> import matplotlib.style
from ggplot import *
>>> matplotlib.style.use("ggplot")
>>> import matplotlib.pyplot as plt
>>>
>>> import numpy
>>> import pandas as pd

# %%
l = pd.DataFrame(d,e)

# %%
k = l.reset_index()

# %%
k.rename(columns={0: '% views'}, inplace=True)
k.rename(columns={"index": '% videos'}, inplace=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
ggplot(aes(x="% videos",y="% views"),data=k)+geom_line(stat="identity")+theme_bw()
# Out:
# <ggplot: (8734157829765)>

# %% [markdown]
# <h2>Configurations</h2>

# %%
tf.reset_default_graph()

# %% [markdown]
# <h3>LSTM with X units</h3>

# %%
n_opt_epoch = 1000
model = 'lstm'
layers = 1
n_samples = 2000
top_k = 15
top_l = 10
top_r = 5

n_users = num_users
te_users = int(np.ceil(num_users*0.2))
n_feature = num_user_feat + num_video_feat + contex_feat #623
lr_rat = 0.01
num_video = h.shape[1]
beta = 0.01

if tr_users > 500:
    batch_size = 500
else:
    batch_size  = tr_users
        
n_hidden = 64 # hidden layer num of features

# %% [markdown]
# Tensorboard saving paths

# %%
! mkdir -p ./reco_rnn/tensor_plot/bpr_max_fix/
! mkdir -p ./reco_rnn/bpr_max_fix/
#logs_path = "/Users/onivron/Desktop/reco_rnn/tensor_plot/p_w/"
logs_path = "./reco_rnn/tensor_plot/bpr_max_fix/"

# %% [markdown]
# <h3>Var creation</h3>
# We build data placeholders & variables

# %%
with tf.name_scope('input'):
    dynam_input = tf.placeholder("float32" ,[batch_size ,None ,n_feature] ,name = 'dynam_input') 
    y_true = tf.placeholder("int32",[None,1] ,name = 'Input_y')
    max_batch_length = tf.placeholder("float32" ,[batch_size] ,name = 'max_leng')
    tr_rw = tf.placeholder("int32" ,[None,1] ,name = '_rw')
    tr_rw_n_desired_rep = tf.placeholder("int32" ,[None, 2] ,name = 'rw_rep')
    
with tf.name_scope("weights"):
    W = {'const': tf.Variable(tf.random_normal([n_feature ,n_hidden])  ,name = 'const_1'),
        'out_2': tf.Variable(tf.random_normal([n_hidden ,num_video]) ,name = 'w_2')}
    
with tf.name_scope("biases"):
    b = {'out_1': tf.Variable(tf.random_normal([batch_size]) ,name = 'b_1'),
        'out_2': tf.Variable(tf.random_normal([num_video]) ,name = 'b_2')}

# %% [markdown]
# <h3>Define model</h3>

# %%
def RNN(dynam_input 
        ,max_batch_length
         ,W ,b ,model):
    
    lstm_cell = rnn_model(model ,n_hidden ,layers)
    
    outputs ,states = tf.nn.dynamic_rnn(lstm_cell ,inputs = dynam_input
                                     ,dtype = tf.float32 ,sequence_length = max_batch_length)
    
    out_shaped = tf.reshape(outputs ,[-1 ,n_hidden])
    lay_2 = (tf.matmul(out_shaped ,W['out_2']) + b['out_2']) 
    return (lay_2)

# %% [markdown]
# <h3>Define loss, accuracy & optimizer</h3>

# %%
y_pred  = RNN(dynam_input, max_batch_length, W, b, model)

with tf.name_scope('bpr_max'):
    target_ind = tf.gather_nd(params = tf.reshape(y_pred, [-1, num_video]), indices = tr_rw_n_desired_rep)
    relevant_y_pred = tf.reshape(tf.gather(params = tf.reshape(y_pred
                                                    , [-1 ,num_video]), indices = tr_rw), [-1, num_video])
    top_neg_vals, top_neg_indice = tf.nn.top_k(relevant_y_pred, n_samples)
    softmax_scores = tf.reshape(tf.nn.softmax(top_neg_vals),[-1])
    
    
    loss = (-(tf.reduce_sum(tf.multiply(tf.log(tf.sigmoid(tf.subtract(target_ind
                                                            , tf.reshape(top_neg_vals, [-1]))))
                                                            ,softmax_scores))))
    regularizer = tf.nn.l2_loss(tf.abs(W['out_2']))
    p_wise = tf.reduce_mean(loss + beta * regularizer)

with tf.name_scope('Accuracy_top_r'):
    top_15_indx_r = tf.slice(top_neg_indice,[0,0],[-1, top_r])
    to_bool_r = tf.reduce_sum(tf.cast(tf.equal(y_true, top_15_indx_r), tf.float32), 1)
    accuracy_r = tf.reduce_mean(to_bool_r)   
    
with tf.name_scope('Accuracy_top_l'):
    top_15_indx_l = tf.slice(top_neg_indice,[0,0],[-1, top_l])
    to_bool_l = tf.reduce_sum(tf.cast(tf.equal(y_true, top_15_indx_l), tf.float32), 1)
    accuracy_l = tf.reduce_mean(to_bool_l)
    
with tf.name_scope('Accuracy_top_k'):
    top_15_indx_k = tf.slice(top_neg_indice,[0,0],[-1,top_k])
    to_bool_k = tf.reduce_sum(tf.cast(tf.equal(y_true, top_15_indx_k), tf.float32), 1)
    accuracy_k = tf.reduce_mean(to_bool_k)

# %%
with tf.name_scope('train'):    
    optimizer = tf.train.AdamOptimizer(learning_rate = lr_rat).minimize(p_wise)

# %% [markdown]
# <h3>Tensorboard set-up</h3>

# %%
tf.summary.scalar("cost" ,p_wise)
tf.summary.scalar("Accuracy_top_r", accuracy_r)
tf.summary.scalar("Accuracy_top_k", accuracy_k)
tf.summary.scalar("Accuracy_top_l", accuracy_l)

summary_op = tf.summary.merge_all()
writer_opt = tf.summary.FileWriter(logs_path ,graph = tf.get_default_graph())
saver = tf.train.Saver(write_version = tf.train.SaverDef.V2)

# %% [markdown]
# <h2>Training - optimization</h2>

# %%
init = tf.global_variables_initializer()
sess = tf.Session() 
sess.run(init)

# %%
#! mkdir -p ./reco_rnn/pair_cost/

# %%
#! aws s3 cp s3://c4-ati/ampapalika/rnn/dataHashed/bpr_max/pair_cost/ ./reco_rnn/pair_cost/ --recursive
# Out:
# download: s3://c4-ati/ampapalika/rnn/dataHashed/bpr_max/pair_cost/checkpoint to reco_rnn/pair_cost/checkpoint
# download: s3://c4-ati/ampapalika/rnn/dataHashed/bpr_max/pair_cost/accu.index to reco_rnn/pair_cost/accu.index
# download: s3://c4-ati/ampapalika/rnn/dataHashed/bpr_max/pair_cost/accu.meta to reco_rnn/pair_cost/accu.meta
# download: s3://c4-ati/ampapalika/rnn/dataHashed/bpr_max/pair_cost/accu.data-00000-of-00001 to reco_rnn/pair_cost/accu.data-00000-of-00001

# %%
save_MDir = './reco_rnn/pair_cost_genre/'
save_model = os.path.join(save_MDir,'accu')
sess=tf.Session() 
sess.run(tf.global_variables_initializer())
saver.restore(sess = sess, save_path= save_model)
# Out:
# INFO:tensorflow:Restoring parameters from ./reco_rnn/pair_cost_genre/accu

# %%
with open('bpr_max_fix_accuracy.csv', 'wb') as csvfile:
    wr = csv.writer(csvfile, delimiter='\t', lineterminator='\n')
    for epoch in range(int(n_opt_epoch)):
        if(epoch != 0):
            writer_opt.add_summary(summary ,epoch)
        for batch_n in range(int(n_users / batch_size)):
            rw_to_chose = np.random.choice((tr_likes["user_id"].unique())  ,batch_size ,replace = False)
            x_tr = sort_pd_df_by_ext_vec(tr_likes
                                         , rw_to_chose, cols = ['user_id','rank'])
            y_batch = sort_pd_df_by_ext_vec(tr_y ,rw_to_chose,cols = ['user_id','rank'])
            length_vec = sort_pd_df_by_ext_vec(df = max_watch ,ext_sor_vec = rw_to_chose ,cols = ['user_id']) 
            length_max = max(length_vec.iloc[:,1])
            str_idx = algeb_geom_series(0 ,start = 0 ,jump = length_max ,length = batch_size)
            end_idx = np.append(length_vec.iloc[0, 1], length_vec.iloc[1:, 1:] + str_idx[1:].reshape(batch_size-1, -1))
            app_range = range_bet_col_t_col_n_append(str_idx, end_idx)
            trial_size = (int(batch_size * length_max), n_feature)
            zero_array_x = np.zeros(trial_size)
            _x_tr = np_pad_tr_x(x_tr.iloc[:,3:], batch_size, str_idx.astype(int),
                                            zero_array_x, length_vec.iloc[:,1].astype(int))       
            rep_ind = np.concatenate((np.repeat(app_range, n_samples).reshape(-1, 1)
                                      , np.repeat(y_batch['desired'], n_samples).reshape(-1, 1)), axis = 1)

            (acc_r, acc_l ,acc_k, p_wise_cost, _, summary) = sess.run([accuracy_r, accuracy_l
                                                                                  , accuracy_k, p_wise 
                                                                                  ,optimizer, summary_op]
                                                      ,feed_dict = {dynam_input: _x_tr.reshape(batch_size, -1, n_feature)
                                                      ,tr_rw_n_desired_rep: rep_ind
                                                      ,tr_rw : app_range.reshape(-1, 1) 
                                                      ,y_true: y_batch['desired'].reshape(-1, 1)
                                                      ,max_batch_length: length_vec.iloc[:, 1]})
            wr.writerow([acc_r])
            wr.writerow([acc_l])
            wr.writerow([acc_k])
            if (epoch%10 == 0):
                print('epoch number:', epoch, 'loss:', p_wise_cost, 'accuracy 15:', acc_k)
                print('epoch number:', epoch, 'accuracy 10:', acc_l)
                print('epoch number:', epoch, 'accuracy 5:', acc_r)


        folder = './reco_rnn/bpr_max_fix/'
        save_path = saver.save(sess, folder + 'accu')
# Out:
# /usr/lib/python2.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/lib/python2.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/lib/python2.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/lib/python2.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# /usr/lib/python2.7/dist-packages/ipykernel_launcher.py:29: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# epoch number: 0 loss: 298513.0 accuracy 15: 0.00184453
# epoch number: 0 accuracy 10: 0.00118282
# epoch number: 0 accuracy 5: 0.000603815
# epoch number: 0 loss: 254617.0 accuracy 15: 0.00205588
# epoch number: 0 accuracy 10: 0.00132342
# epoch number: 0 accuracy 5: 0.000649226
# epoch number: 0 loss: 231958.0 accuracy 15: 0.0019306
# epoch number: 0 accuracy 10: 0.00120239
# epoch number: 0 accuracy 5: 0.000541923
# epoch number: 10 loss: 109347.0 accuracy 15: 0.0926375
# epoch number: 10 accuracy 10: 0.0778129
# epoch number: 10 accuracy 5: 0.0560246
# epoch number: 10 loss: 106864.0 accuracy 15: 0.102122
# epoch number: 10 accuracy 10: 0.087028
# epoch number: 10 accuracy 5: 0.0641508
# epoch number: 10 loss: 104306.0 accuracy 15: 0.111925
# epoch number: 10 accuracy 10: 0.0966553
# epoch number: 10 accuracy 5: 0.0733158
# epoch number: 20 loss: 76232.9 accuracy 15: 0.280443
# epoch number: 20 accuracy 10: 0.258679
# epoch number: 20 accuracy 5: 0.22464
# epoch number: 20 loss: 73619.2 accuracy 15: 0.288262
# epoch number: 20 accuracy 10: 0.266235
# epoch number: 20 accuracy 5: 0.231623
# epoch number: 20 loss: 74961.3 accuracy 15: 0.285789
# epoch number: 20 accuracy 10: 0.264553
# epoch number: 20 accuracy 5: 0.231106

# %% [markdown]
# # Testing

# %%
rw_to_chose = np.random.choice(range(int(tr_users), n_users)
                               , n_users - int(tr_users), replace = False)
x_tr = sort_pd_df_by_ext_vec(user_vid_time_vidfeat_usefit_sorted
                             , rw_to_chose, cols = ['user_id','time_watch'])
y_batch = sort_pd_df_by_ext_vec(te_y ,rw_to_chose,cols = ['user','rank'])
length_vec = sort_pd_df_by_ext_vec(df = max_watch ,ext_sor_vec = rw_to_chose ,cols = ['user']) 
length_max = max(length_vec.iloc[:,1])
str_idx = algeb_geom_series(0 ,start = 0 ,jump = length_max ,length = batch_size)
end_idx = np.append(length_vec.iloc[0, 1], length_vec.iloc[1:, 1:] + str_idx[1:].reshape(batch_size-1, -1))
app_range = range_bet_col_t_col_n_append(str_idx, end_idx)
trial_size = (int(batch_size * length_max), n_feature)
zero_array_x = np.zeros(trial_size) ; zero_array_x_dis = np.zeros(trial_size)
_x_tr = np_pad_tr_x(x_tr.iloc[:,3:], batch_size, str_idx.astype(int),
                                zero_array_x, length_vec.iloc[:,1].astype(int))
_x_tr_dis = np_pad_tr_x(x_tr_dis.iloc[:,3:], batch_size, str_idx.astype(int),
                                zero_array_x_dis, length_vec.iloc[:,1].astype(int))  
rep_ind = np.concatenate((np.repeat(app_range, n_samples).reshape(-1, 1)
                          , np.repeat(y_batch['desired'], n_samples).reshape(-1, 1)), axis = 1)
non_rep = np.concatenate((app_range).reshape(-1, 1)
                          , (y_batch['desired']).reshape(-1, 1), axis = 1)
 (test_accuracy_r, test_accuracy_l ,test_accuracy_k, test_loss  )
    = sess.run([ accuracy_r, accuracy_l , accuracy_k, p_wise]
                                          ,feed_dict = {dynam_input: _x_tr.reshape(batch_size, -1, n_feature)
                                          ,dislike_inp: _x_tr_dis.reshape(batch_size, -1, n_feature)
                                          ,tr_rw_n_desired_rep: rep_ind
                                          ,tr_rw : app_range.reshape(-1, 1) 
                                          ,y_true: y_batch['desired'].reshape(-1, 1)
                                          ,max_batch_length: length_vec.iloc[:, 1]})

print('accuracy top 5:', test_accuracy_r) 
print('accuracy top 10:', test_accuracy_l) 
print('accuracy top 15:', test_accuracy_k)

# %% [markdown]
# <h3>End session</h3>

# %%
sess.close()
